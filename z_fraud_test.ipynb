# %%
import os 
datapath = os.path.join("Data/")
import pandas as pd

# %%
another_fraud_train_df = pd.read_csv(datapath + "fraudTrain.csv")
another_fraud_test_df = pd.read_csv(datapath + "fraudTest.csv")

# %%
another_fraud_train_df.head(2)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
#
#                           merchant     category     amt      first   last  \
# 0       fraud_Rippin, Kub and Mann     misc_net    4.97   Jennifer  Banks
# 1  fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie   Gill
#
#   gender                        street  ...      lat      long  city_pop  \
# 0      F                561 Perry Cove  ...  36.0788  -81.1781      3495
# 1      F  43039 Riley Greens Suite 393  ...  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# ...

# %%
another_fraud_test_df.head(2)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num               merchant  \
# 0           0   2020-06-21 12:14:25  2291163933867244  fraud_Kirlin and Sons
# 1           1   2020-06-21 12:14:33  3573030041201292   fraud_Sporer-Keebler
#
#         category    amt   first      last gender             street  ...  \
# 0  personal_care   2.86    Jeff   Elliott      M  351 Darlene Green  ...
# 1  personal_care  29.84  Joanne  Williams      F   3638 Marsh Union  ...
#
#        lat      long  city_pop                     job         dob  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1968-03-19
# 1  40.3207 -110.4360       302  Sales professional, IT  1990-01-17
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
#
#    is_fraud
# 0         0
# 1         0
#
# [2 rows x 23 columns]

# %%
another_fraud_train_df["is_fraud"].value_counts() , another_fraud_test_df["is_fraud"].value_counts()
# Out:
# (0    1289169
#  1       7506
#  Name: is_fraud, dtype: int64,
#  0    553574
#  1      2145
#  Name: is_fraud, dtype: int64)

# %%
print(f' Train_Data merchat : \n{another_fraud_train_df["merchant"].value_counts()} \n' \
    f' Test_Data merchant : \n{another_fraud_test_df["merchant"].value_counts()}')
# Out:
#  Train_Data merchat :
# fraud_Kilback LLC                       4403
# fraud_Cormier LLC                       3649
# fraud_Schumm PLC                        3634
# fraud_Kuhn LLC                          3510
# fraud_Boyer PLC                         3493
#                                         ...
# fraud_Douglas, DuBuque and McKenzie      775
# fraud_Treutel-King                       775
# fraud_Medhurst, Labadie and Gottlieb     759
# fraud_Reichert-Weissnat                  753
# fraud_Hahn, Douglas and Schowalter       727
# Name: merchant, Length: 693, dtype: int64
#  Test_Data merchant :
# fraud_Kilback LLC                        1859
# fraud_Cormier LLC                        1597
# fraud_Schumm PLC                         1561
# fraud_Kuhn LLC                           1521
# fraud_Dickinson Ltd                      1519
#                                          ...
# fraud_Treutel-King                        323
# fraud_Satterfield-Lowe                    319
# ...
